# %%
import cv2
import pandas as pd
import numpy as np
import torch
from ultralytics import YOLO
from tracker import Tracker

# %%
model = YOLO('models/yolo12s.pt')  

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# Filter classes to track only vehicles
my_class = ['car', 'motorcycle', 'bus', 'truck', 'rickshaw', 'lorry','bicyle']

# %%
tracker=Tracker()
video_path = 'videos/road_feed.mp4'
video = cv2.VideoCapture(video_path)

fps = video.get(cv2.CAP_PROP_FPS)
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(f"Video FPS: {fps}, Resolution: {width}x{height}")
# Out:
# Video FPS: 24.0, Resolution: 360x640

# %%
vehicle_counts = {
    'car': 0,
    'motorcycle': 0,
    'bus': 0,
    'truck': 0,
    'rickshaw': 0,
    'lorry': 0
}

# %%
counted_ids = set()

frame_dict = {}
frame_no = 0

previous_positions = {}

# %%
def search_frame(current, target_id):
    for frame in range(current, 0, -1):
        for data in frame_dict[frame]:
            id, cx, cy = data
            if id == target_id:
                return [frame, cx, cy]
    return None

def distance(xs, ys, xe, ye):
    return np.sqrt((xe - xs)**2 + (ye - ys)**2)

# %%
counter_line_y = 540  


real_world_distance = 4.0
pixel_distance = 100
pixel_to_meter_ratio = real_world_distance / pixel_distance 

while True:
    ret, frame = video.read()
    if not ret:
        break

    frame = cv2.resize(frame, (540, 960))

    results = model.predict(frame)
    temp = results[0].boxes.data
    temp = temp.detach().cpu().numpy()
    bb_df = pd.DataFrame(temp).astype("int")


    bb_list = []
    for index, row in bb_df.iterrows():
        x1, y1, x2, y2, sc, d = row
        c = class_list[d]
        if c in my_class:
            bb_list.append([x1, y1, x2, y2, sc, c])

    bbox_ids = tracker.update(bb_list)

    # Draw bounding boxes and IDs on the frame
    for bbox in bbox_ids:
        x3, y3, x4, y4, sc, c, id = bbox
        cx = int(x3 + x4) // 2
        cy = int(y3 + y4) // 2

        # Draw bounding box and label
        cv2.putText(frame, str(c), (x3, y3 - 2), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (255, 255, 255), 1)
        cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 1)


        # Check if vehicle crosses the counter line
        offset = 5
        if counter_line_y < (cy + offset) and counter_line_y > (cy - offset):
            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            cv2.putText(frame, str(id), (cx, cy), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)

            # Ensure each vehicle is counted only once
            if id not in counted_ids:
                counted_ids.add(id)
                vehicle_counts[c] += 1

        # Calculate speed if the vehicle was detected in the previous frame
        if id in previous_positions:
            prev_cx, prev_cy = previous_positions[id]
            pixel_distance_traveled = np.sqrt((cx - prev_cx)**2 + (cy - prev_cy)**2)  # Distance in pixels
            real_distance_traveled = pixel_distance_traveled * pixel_to_meter_ratio  # Distance in meters
            time_elapsed = 1 / fps  # Time in seconds
            speed = (real_distance_traveled / time_elapsed) * 3.6  # Convert to km/h

            cv2.putText(frame, f"{speed:.2f} km/h", (cx, cy + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)

        previous_positions[id] = (cx, cy)

    y_offset = 40
    for vehicle_type, count in vehicle_counts.items():
        cv2.putText(frame, f'{vehicle_type}: {count}', (60, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
        y_offset += 30  # Move down for the next line

    cv2.putText(frame, f'Total Vehicles: {len(counted_ids)}', (60, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    cv2.imshow("Vehicle Detection", frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 10 cars, 408.8ms
# Speed: 17.6ms preprocess, 408.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 162.8ms
# Speed: 3.2ms preprocess, 162.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 141.9ms
# Speed: 2.5ms preprocess, 141.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 155.2ms
# Speed: 2.5ms preprocess, 155.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 151.0ms
# Speed: 3.3ms preprocess, 151.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 147.4ms
# Speed: 2.6ms preprocess, 147.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 148.7ms
# Speed: 2.5ms preprocess, 148.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 170.0ms
# Speed: 2.8ms preprocess, 170.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 147.3ms
# Speed: 2.6ms preprocess, 147.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 143.9ms
# Speed: 2.7ms preprocess, 143.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 134.3ms
# Speed: 2.4ms preprocess, 134.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 127.7ms
# Speed: 2.3ms preprocess, 127.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 127.3ms
# Speed: 2.2ms preprocess, 127.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 135.2ms
# Speed: 2.4ms preprocess, 135.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 137.2ms
# Speed: 3.1ms preprocess, 137.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 142.7ms
# Speed: 2.5ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 147.5ms
# Speed: 3.0ms preprocess, 147.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 138.8ms
# Speed: 2.4ms preprocess, 138.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 131.4ms
# Speed: 2.5ms preprocess, 131.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 144.4ms
# Speed: 3.1ms preprocess, 144.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 140.2ms
# Speed: 2.5ms preprocess, 140.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 132.1ms
# Speed: 2.3ms preprocess, 132.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 136.1ms
# Speed: 2.7ms preprocess, 136.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 136.0ms
# Speed: 2.4ms preprocess, 136.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 119.9ms
# Speed: 2.5ms preprocess, 119.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 135.3ms
# Speed: 2.2ms preprocess, 135.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 12 cars, 131.4ms
# Speed: 2.4ms preprocess, 131.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 143.8ms
# Speed: 2.5ms preprocess, 143.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 142.3ms
# Speed: 2.4ms preprocess, 142.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 12 cars, 132.8ms
# Speed: 2.3ms preprocess, 132.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 125.8ms
# Speed: 2.4ms preprocess, 125.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 133.7ms
# Speed: 2.5ms preprocess, 133.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 137.6ms
# Speed: 2.4ms preprocess, 137.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 121.4ms
# Speed: 2.4ms preprocess, 121.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 141.5ms
# Speed: 2.6ms preprocess, 141.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 134.8ms
# Speed: 2.7ms preprocess, 134.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 138.5ms
# Speed: 2.3ms preprocess, 138.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 131.5ms
# Speed: 2.4ms preprocess, 131.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 128.4ms
# Speed: 2.2ms preprocess, 128.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 135.4ms
# Speed: 1.9ms preprocess, 135.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 126.9ms
# Speed: 2.3ms preprocess, 126.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 137.9ms
# Speed: 3.0ms preprocess, 137.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 136.7ms
# Speed: 2.4ms preprocess, 136.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 127.3ms
# Speed: 2.3ms preprocess, 127.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 126.6ms
# Speed: 2.5ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 165.2ms
# Speed: 3.0ms preprocess, 165.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 138.2ms
# Speed: 2.3ms preprocess, 138.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 138.5ms
# Speed: 2.4ms preprocess, 138.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 142.5ms
# Speed: 2.4ms preprocess, 142.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 128.1ms
# Speed: 2.4ms preprocess, 128.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 137.9ms
# Speed: 2.2ms preprocess, 137.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 129.8ms
# Speed: 2.4ms preprocess, 129.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 141.8ms
# Speed: 2.6ms preprocess, 141.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 139.7ms
# Speed: 2.4ms preprocess, 139.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 132.7ms
# Speed: 2.8ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 136.2ms
# Speed: 2.4ms preprocess, 136.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 138.8ms
# Speed: 2.2ms preprocess, 138.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 134.4ms
# Speed: 2.5ms preprocess, 134.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 133.2ms
# Speed: 2.3ms preprocess, 133.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 140.8ms
# Speed: 2.5ms preprocess, 140.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 134.4ms
# Speed: 2.3ms preprocess, 134.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 141.4ms
# Speed: 2.2ms preprocess, 141.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 138.8ms
# Speed: 2.7ms preprocess, 138.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 128.9ms
# Speed: 2.2ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 133.4ms
# Speed: 2.3ms preprocess, 133.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 131.8ms
# Speed: 2.4ms preprocess, 131.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 133.5ms
# Speed: 2.4ms preprocess, 133.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 132.8ms
# Speed: 2.6ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 136.0ms
# Speed: 2.1ms preprocess, 136.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 139.7ms
# Speed: 2.4ms preprocess, 139.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 137.6ms
# Speed: 1.8ms preprocess, 137.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 136.5ms
# Speed: 2.8ms preprocess, 136.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 136.2ms
# Speed: 2.4ms preprocess, 136.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 136.2ms
# Speed: 2.5ms preprocess, 136.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 134.6ms
# Speed: 2.4ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 12 cars, 134.4ms
# Speed: 2.3ms preprocess, 134.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 12 cars, 136.2ms
# Speed: 2.4ms preprocess, 136.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 164.2ms
# Speed: 2.5ms preprocess, 164.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 138.5ms
# Speed: 2.7ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 132.0ms
# Speed: 2.5ms preprocess, 132.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 120.7ms
# Speed: 2.6ms preprocess, 120.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 137.1ms
# Speed: 2.6ms preprocess, 137.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 136.4ms
# Speed: 2.3ms preprocess, 136.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 134.6ms
# Speed: 2.4ms preprocess, 134.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 140.9ms
# Speed: 2.4ms preprocess, 140.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 140.8ms
# Speed: 2.0ms preprocess, 140.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 cars, 136.2ms
# Speed: 2.8ms preprocess, 136.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 139.5ms
# Speed: 2.6ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 135.8ms
# Speed: 2.8ms preprocess, 135.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 138.1ms
# Speed: 2.2ms preprocess, 138.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 137.1ms
# Speed: 2.4ms preprocess, 137.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 126.5ms
# Speed: 1.9ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 136.1ms
# Speed: 2.3ms preprocess, 136.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 127.5ms
# Speed: 2.5ms preprocess, 127.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 142.0ms
# Speed: 2.2ms preprocess, 142.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 144.0ms
# Speed: 2.5ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 126.6ms
# Speed: 2.2ms preprocess, 126.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 125.0ms
# Speed: 2.6ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 134.7ms
# Speed: 2.1ms preprocess, 134.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 129.7ms
# Speed: 2.5ms preprocess, 129.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 139.8ms
# Speed: 2.3ms preprocess, 139.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 126.7ms
# Speed: 2.1ms preprocess, 126.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 176.2ms
# Speed: 2.3ms preprocess, 176.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 129.3ms
# Speed: 2.4ms preprocess, 129.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 135.0ms
# Speed: 3.1ms preprocess, 135.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 135.5ms
# Speed: 2.7ms preprocess, 135.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 141.3ms
# Speed: 2.3ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 146.5ms
# Speed: 2.4ms preprocess, 146.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 140.7ms
# Speed: 2.3ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 cars, 143.1ms
# Speed: 2.3ms preprocess, 143.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 136.4ms
# Speed: 2.2ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 138.1ms
# Speed: 2.6ms preprocess, 138.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 149.2ms
# Speed: 2.7ms preprocess, 149.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 137.5ms
# Speed: 2.5ms preprocess, 137.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 cars, 141.8ms
# Speed: 2.3ms preprocess, 141.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 137.2ms
# Speed: 2.7ms preprocess, 137.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 143.3ms
# Speed: 2.7ms preprocess, 143.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 1 motorcycle, 144.9ms
# Speed: 2.4ms preprocess, 144.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 140.2ms
# Speed: 2.3ms preprocess, 140.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 137.3ms
# Speed: 2.3ms preprocess, 137.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 143.3ms
# Speed: 2.3ms preprocess, 143.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 1 motorcycle, 165.7ms
# Speed: 2.8ms preprocess, 165.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 1 motorcycle, 130.4ms
# Speed: 1.9ms preprocess, 130.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 1 motorcycle, 147.9ms
# Speed: 2.6ms preprocess, 147.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 1 motorcycle, 152.0ms
# Speed: 2.3ms preprocess, 152.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 1 motorcycle, 135.3ms
# Speed: 3.1ms preprocess, 135.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 1 motorcycle, 142.6ms
# Speed: 2.6ms preprocess, 142.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 2 motorcycles, 139.9ms
# Speed: 2.5ms preprocess, 139.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 1 motorcycle, 159.1ms
# Speed: 2.3ms preprocess, 159.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 2 motorcycles, 145.3ms
# Speed: 2.5ms preprocess, 145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 10 cars, 1 motorcycle, 137.9ms
# Speed: 2.7ms preprocess, 137.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 1 motorcycle, 141.7ms
# Speed: 2.5ms preprocess, 141.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 2 motorcycles, 141.2ms
# Speed: 2.3ms preprocess, 141.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 9 cars, 3 motorcycles, 146.6ms
# Speed: 2.7ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 1 motorcycle, 143.0ms
# Speed: 2.5ms preprocess, 143.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 1 motorcycle, 124.0ms
# Speed: 3.6ms preprocess, 124.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 10 cars, 1 motorcycle, 168.2ms
# Speed: 2.2ms preprocess, 168.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 11 cars, 1 motorcycle, 134.5ms
# Speed: 2.3ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 cars, 1 motorcycle, 142.5ms
# Speed: 2.1ms preprocess, 142.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 11 cars, 1 motorcycle, 179.5ms
# Speed: 2.8ms preprocess, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 11 cars, 1 motorcycle, 136.7ms
# Speed: 2.3ms preprocess, 136.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 11 cars, 130.7ms
# Speed: 2.2ms preprocess, 130.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 11 cars, 1 motorcycle, 138.4ms
# Speed: 2.7ms preprocess, 138.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 11 cars, 1 motorcycle, 135.5ms
# Speed: 2.7ms preprocess, 135.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 9 cars, 1 motorcycle, 144.1ms
# Speed: 2.3ms preprocess, 144.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 9 cars, 2 motorcycles, 136.7ms
# Speed: 2.3ms preprocess, 136.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 9 cars, 1 motorcycle, 142.2ms
# Speed: 2.6ms preprocess, 142.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 1 motorcycle, 142.5ms
# Speed: 2.5ms preprocess, 142.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 140.6ms
# Speed: 2.3ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 147.6ms
# Speed: 2.4ms preprocess, 147.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 144.3ms
# Speed: 2.3ms preprocess, 144.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 2 motorcycles, 136.1ms
# Speed: 2.2ms preprocess, 136.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 1 motorcycle, 137.5ms
# Speed: 2.1ms preprocess, 137.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 1 motorcycle, 117.8ms
# Speed: 2.3ms preprocess, 117.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 1 motorcycle, 158.5ms
# Speed: 3.0ms preprocess, 158.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 182.2ms
# Speed: 2.4ms preprocess, 182.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 144.2ms
# Speed: 2.6ms preprocess, 144.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 149.8ms
# Speed: 2.7ms preprocess, 149.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 8 cars, 1 motorcycle, 143.5ms
# Speed: 2.1ms preprocess, 143.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 8 cars, 1 motorcycle, 139.1ms
# Speed: 2.5ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 147.3ms
# Speed: 2.5ms preprocess, 147.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 2 motorcycles, 149.6ms
# Speed: 2.4ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 2 motorcycles, 134.3ms
# Speed: 2.5ms preprocess, 134.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 146.8ms
# Speed: 2.5ms preprocess, 146.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 1 motorcycle, 136.6ms
# Speed: 2.5ms preprocess, 136.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 7 cars, 1 motorcycle, 145.2ms
# Speed: 2.5ms preprocess, 145.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 1 motorcycle, 130.3ms
# Speed: 2.5ms preprocess, 130.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 8 cars, 1 motorcycle, 143.5ms
# Speed: 2.7ms preprocess, 143.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 9 cars, 1 motorcycle, 131.0ms
# Speed: 2.5ms preprocess, 131.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 1 motorcycle, 139.1ms
# Speed: 2.4ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 9 cars, 1 motorcycle, 139.4ms
# Speed: 2.5ms preprocess, 139.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 9 cars, 189.5ms
# Speed: 2.2ms preprocess, 189.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 1 motorcycle, 130.4ms
# Speed: 2.3ms preprocess, 130.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 8 cars, 1 motorcycle, 123.3ms
# Speed: 2.3ms preprocess, 123.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 2 motorcycles, 139.0ms
# Speed: 2.4ms preprocess, 139.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 140.3ms
# Speed: 2.5ms preprocess, 140.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 8 cars, 1 motorcycle, 122.9ms
# Speed: 2.2ms preprocess, 122.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 8 cars, 1 motorcycle, 136.0ms
# Speed: 3.6ms preprocess, 136.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 2 motorcycles, 134.7ms
# Speed: 2.1ms preprocess, 134.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 142.6ms
# Speed: 2.4ms preprocess, 142.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 150.8ms
# Speed: 2.6ms preprocess, 150.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 1 motorcycle, 130.2ms
# Speed: 2.6ms preprocess, 130.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 128.1ms
# Speed: 2.3ms preprocess, 128.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 175.4ms
# Speed: 3.5ms preprocess, 175.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 152.2ms
# Speed: 2.7ms preprocess, 152.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 3 motorcycles, 178.5ms
# Speed: 2.2ms preprocess, 178.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 3 motorcycles, 137.2ms
# Speed: 2.5ms preprocess, 137.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 2 motorcycles, 138.6ms
# Speed: 2.7ms preprocess, 138.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 140.7ms
# Speed: 2.1ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 145.9ms
# Speed: 2.3ms preprocess, 145.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 127.6ms
# Speed: 3.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 134.9ms
# Speed: 2.7ms preprocess, 134.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 142.3ms
# Speed: 2.6ms preprocess, 142.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 141.9ms
# Speed: 2.9ms preprocess, 141.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 133.7ms
# Speed: 3.7ms preprocess, 133.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 130.2ms
# Speed: 2.4ms preprocess, 130.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 127.4ms
# Speed: 2.3ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 134.8ms
# Speed: 2.2ms preprocess, 134.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 2 motorcycles, 1 fire hydrant, 131.7ms
# Speed: 3.1ms preprocess, 131.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 1 motorcycle, 175.1ms
# Speed: 2.7ms preprocess, 175.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 1 motorcycle, 141.4ms
# Speed: 2.3ms preprocess, 141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 142.7ms
# Speed: 2.3ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 6 cars, 131.8ms
# Speed: 2.6ms preprocess, 131.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 129.2ms
# Speed: 2.3ms preprocess, 129.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 2 motorcycles, 143.6ms
# Speed: 2.3ms preprocess, 143.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 6 cars, 1 motorcycle, 143.1ms
# Speed: 2.4ms preprocess, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 6 cars, 1 motorcycle, 139.3ms
# Speed: 1.9ms preprocess, 139.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 6 cars, 3 motorcycles, 142.3ms
# Speed: 2.4ms preprocess, 142.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 motorcycle, 143.1ms
# Speed: 2.4ms preprocess, 143.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 140.4ms
# Speed: 2.4ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 6 cars, 142.4ms
# Speed: 2.5ms preprocess, 142.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 6 cars, 143.4ms
# Speed: 2.5ms preprocess, 143.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 198.5ms
# Speed: 2.5ms preprocess, 198.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 137.2ms
# Speed: 2.3ms preprocess, 137.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 6 cars, 137.9ms
# Speed: 2.4ms preprocess, 137.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 6 cars, 1 motorcycle, 143.2ms
# Speed: 2.3ms preprocess, 143.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 6 cars, 1 motorcycle, 140.2ms
# Speed: 2.6ms preprocess, 140.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 140.6ms
# Speed: 2.2ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 124.4ms
# Speed: 2.5ms preprocess, 124.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 6 cars, 128.4ms
# Speed: 2.3ms preprocess, 128.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 6 cars, 130.1ms
# Speed: 2.4ms preprocess, 130.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 140.7ms
# Speed: 2.3ms preprocess, 140.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 7 cars, 1 motorcycle, 136.1ms
# Speed: 2.4ms preprocess, 136.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 1 motorcycle, 137.7ms
# Speed: 2.5ms preprocess, 137.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 7 cars, 1 motorcycle, 202.7ms
# Speed: 2.1ms preprocess, 202.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 7 cars, 143.7ms
# Speed: 2.6ms preprocess, 143.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 147.7ms
# Speed: 2.5ms preprocess, 147.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 142.7ms
# Speed: 2.6ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 141.9ms
# Speed: 2.5ms preprocess, 141.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 8 cars, 145.6ms
# Speed: 2.6ms preprocess, 145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 8 cars, 139.5ms
# Speed: 2.7ms preprocess, 139.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 143.4ms
# Speed: 2.4ms preprocess, 143.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 143.0ms
# Speed: 2.7ms preprocess, 143.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 138.0ms
# Speed: 2.3ms preprocess, 138.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 7 cars, 1 motorcycle, 142.6ms
# Speed: 2.9ms preprocess, 142.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 8 cars, 186.8ms
# Speed: 2.4ms preprocess, 186.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 8 cars, 136.2ms
# Speed: 2.3ms preprocess, 136.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
